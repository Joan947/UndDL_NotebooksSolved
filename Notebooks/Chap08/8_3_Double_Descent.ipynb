# %% [markdown]
# <a href="https://colab.research.google.com/github/Joan947/UndDL_NotebooksSolved/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-d7yfgtij
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-d7yfgtij
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=213c5f91e40070bfd23d459c46cbe3ca4f9d4d07cfdc01713a1958e0bd23c74e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2hhar36s/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.215745, train error 80.88,  test loss 2.176387, test error 78.62
# Epoch   100, train loss 1.862305, train error 71.18,  test loss 1.710380, test error 68.50
# Epoch   200, train loss 1.852755, train error 71.07,  test loss 1.696391, test error 68.25
# Epoch   300, train loss 1.851623, train error 70.95,  test loss 1.697803, test error 68.38
# Epoch   400, train loss 1.853215, train error 71.12,  test loss 1.708197, test error 67.55
# Epoch   500, train loss 1.855071, train error 70.90,  test loss 1.689044, test error 67.57
# Epoch   600, train loss 1.847005, train error 70.38,  test loss 1.688038, test error 67.62
# Epoch   700, train loss 1.850449, train error 71.78,  test loss 1.699154, test error 69.05
# Epoch   800, train loss 1.844740, train error 70.57,  test loss 1.701021, test error 67.38
# Epoch   900, train loss 1.849780, train error 70.57,  test loss 1.705091, test error 67.18
# Training model with   4 hidden variables
# Epoch     0, train loss 2.275904, train error 85.97,  test loss 2.263090, test error 84.88
# Epoch   100, train loss 1.836094, train error 66.10,  test loss 1.688040, test error 64.90
# Epoch   200, train loss 1.751919, train error 62.35,  test loss 1.582207, test error 59.10
# Epoch   300, train loss 1.723182, train error 59.55,  test loss 1.511985, test error 57.17
# Epoch   400, train loss 1.704879, train error 58.58,  test loss 1.489508, test error 54.78
# Epoch   500, train loss 1.703967, train error 58.03,  test loss 1.491233, test error 56.05
# Epoch   600, train loss 1.696831, train error 58.10,  test loss 1.493745, test error 55.53
# Epoch   700, train loss 1.712243, train error 58.38,  test loss 1.517656, test error 55.97
# Epoch   800, train loss 1.691995, train error 57.88,  test loss 1.474541, test error 54.62
# Epoch   900, train loss 1.696874, train error 58.62,  test loss 1.488059, test error 55.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.303164, train error 87.00,  test loss 2.304146, test error 87.40
# Epoch   100, train loss 1.711778, train error 61.00,  test loss 1.514844, test error 58.40
# Epoch   200, train loss 1.692346, train error 61.42,  test loss 1.508804, test error 59.50
# Epoch   300, train loss 1.692357, train error 61.17,  test loss 1.509581, test error 58.75
# Epoch   400, train loss 1.684702, train error 60.92,  test loss 1.511560, test error 59.75
# Epoch   500, train loss 1.677810, train error 61.12,  test loss 1.515397, test error 59.70
# Epoch   600, train loss 1.681301, train error 60.20,  test loss 1.513824, test error 59.47
# Epoch   700, train loss 1.676727, train error 60.75,  test loss 1.526624, test error 59.70
# Epoch   800, train loss 1.667018, train error 59.50,  test loss 1.518242, test error 59.22
# Epoch   900, train loss 1.696641, train error 61.45,  test loss 1.552899, test error 60.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.254935, train error 84.90,  test loss 2.244790, test error 85.15
# Epoch   100, train loss 1.622111, train error 57.40,  test loss 1.463205, test error 56.35
# Epoch   200, train loss 1.581302, train error 56.53,  test loss 1.436295, test error 55.28
# Epoch   300, train loss 1.561929, train error 55.55,  test loss 1.465822, test error 55.85
# Epoch   400, train loss 1.547005, train error 55.17,  test loss 1.460626, test error 55.10
# Epoch   500, train loss 1.539201, train error 54.92,  test loss 1.465012, test error 54.88
# Epoch   600, train loss 1.533767, train error 54.15,  test loss 1.468854, test error 54.55
# Epoch   700, train loss 1.533412, train error 54.40,  test loss 1.470535, test error 54.67
# Epoch   800, train loss 1.531846, train error 54.10,  test loss 1.467102, test error 54.10
# Epoch   900, train loss 1.531510, train error 55.28,  test loss 1.475119, test error 55.30
# Training model with  10 hidden variables
# Epoch     0, train loss 2.213570, train error 81.47,  test loss 2.201347, test error 80.72
# Epoch   100, train loss 1.502183, train error 50.40,  test loss 1.365447, test error 52.62
# Epoch   200, train loss 1.442474, train error 48.33,  test loss 1.313485, test error 48.75
# Epoch   300, train loss 1.425521, train error 47.45,  test loss 1.321839, test error 49.45
# Epoch   400, train loss 1.415027, train error 46.97,  test loss 1.308184, test error 49.08
# Epoch   500, train loss 1.413218, train error 46.88,  test loss 1.306486, test error 49.10
# Epoch   600, train loss 1.413342, train error 47.10,  test loss 1.308571, test error 49.28
# Epoch   700, train loss 1.414000, train error 47.05,  test loss 1.321124, test error 48.47
# Epoch   800, train loss 1.407496, train error 45.83,  test loss 1.323364, test error 48.95
# Epoch   900, train loss 1.401206, train error 46.33,  test loss 1.332110, test error 49.20
# Training model with  14 hidden variables
# Epoch     0, train loss 2.257050, train error 84.78,  test loss 2.268655, test error 85.22
# Epoch   100, train loss 1.426890, train error 48.12,  test loss 1.293882, test error 48.95
# Epoch   200, train loss 1.333534, train error 44.33,  test loss 1.247843, test error 46.28
# Epoch   300, train loss 1.309119, train error 43.08,  test loss 1.261991, test error 46.62
# Epoch   400, train loss 1.298972, train error 43.17,  test loss 1.272951, test error 47.05
# Epoch   500, train loss 1.293248, train error 43.38,  test loss 1.308602, test error 47.95
# Epoch   600, train loss 1.291637, train error 43.42,  test loss 1.319889, test error 48.33
# Epoch   700, train loss 1.281911, train error 43.42,  test loss 1.334245, test error 48.20
# Epoch   800, train loss 1.279885, train error 43.00,  test loss 1.354561, test error 49.50
# Epoch   900, train loss 1.277478, train error 42.75,  test loss 1.361657, test error 49.00
# Training model with  18 hidden variables
# Epoch     0, train loss 2.259104, train error 85.38,  test loss 2.245205, test error 84.30
# Epoch   100, train loss 1.327285, train error 44.20,  test loss 1.281961, test error 48.28
# Epoch   200, train loss 1.246400, train error 41.30,  test loss 1.309462, test error 49.03
# Epoch   300, train loss 1.198256, train error 39.12,  test loss 1.369281, test error 49.85
# Epoch   400, train loss 1.176123, train error 38.67,  test loss 1.408518, test error 50.88
# Epoch   500, train loss 1.163785, train error 38.45,  test loss 1.457787, test error 51.47
# Epoch   600, train loss 1.141964, train error 37.97,  test loss 1.478747, test error 51.40
# Epoch   700, train loss 1.131897, train error 37.55,  test loss 1.503851, test error 51.88
# Epoch   800, train loss 1.127319, train error 37.75,  test loss 1.518850, test error 52.10
# Epoch   900, train loss 1.129552, train error 37.72,  test loss 1.541136, test error 52.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.218611, train error 81.28,  test loss 2.204171, test error 80.97
# Epoch   100, train loss 1.314569, train error 44.30,  test loss 1.386058, test error 52.47
# Epoch   200, train loss 1.178478, train error 39.05,  test loss 1.413734, test error 51.15
# Epoch   300, train loss 1.118639, train error 37.65,  test loss 1.459447, test error 51.38
# Epoch   400, train loss 1.084599, train error 36.47,  test loss 1.533229, test error 52.22
# Epoch   500, train loss 1.054906, train error 35.40,  test loss 1.578826, test error 52.62
# Epoch   600, train loss 1.034971, train error 35.55,  test loss 1.612915, test error 52.83
# Epoch   700, train loss 1.012792, train error 33.95,  test loss 1.669102, test error 52.78
# Epoch   800, train loss 1.019783, train error 35.10,  test loss 1.719765, test error 53.60
# Epoch   900, train loss 0.997821, train error 33.95,  test loss 1.757017, test error 52.97
# Training model with  26 hidden variables
# Epoch     0, train loss 2.156082, train error 79.53,  test loss 2.131735, test error 78.12
# Epoch   100, train loss 1.176394, train error 38.30,  test loss 1.334181, test error 48.67
# Epoch   200, train loss 1.056818, train error 34.50,  test loss 1.458045, test error 50.53
# Epoch   300, train loss 0.991714, train error 32.70,  test loss 1.590220, test error 51.75
# Epoch   400, train loss 0.948390, train error 30.97,  test loss 1.686593, test error 52.42
# Epoch   500, train loss 0.934839, train error 31.18,  test loss 1.792548, test error 52.92
# Epoch   600, train loss 0.899741, train error 30.12,  test loss 1.870282, test error 53.75
# Epoch   700, train loss 0.899118, train error 30.68,  test loss 1.950600, test error 54.08
# Epoch   800, train loss 0.870992, train error 28.97,  test loss 2.030359, test error 54.53
# Epoch   900, train loss 0.868774, train error 28.85,  test loss 2.095845, test error 54.58
# Training model with  30 hidden variables
# Epoch     0, train loss 2.239504, train error 83.97,  test loss 2.225386, test error 83.03
# Epoch   100, train loss 1.123566, train error 36.80,  test loss 1.365824, test error 50.05
# Epoch   200, train loss 0.956022, train error 31.75,  test loss 1.553733, test error 50.90
# Epoch   300, train loss 0.850414, train error 27.93,  test loss 1.765125, test error 52.65
# Epoch   400, train loss 0.809708, train error 28.15,  test loss 1.942569, test error 54.38
# Epoch   500, train loss 0.755003, train error 25.88,  test loss 2.063169, test error 55.08
# Epoch   600, train loss 0.711108, train error 24.12,  test loss 2.222142, test error 55.20
# Epoch   700, train loss 0.693488, train error 23.47,  test loss 2.321256, test error 54.53
# Epoch   800, train loss 0.683022, train error 23.47,  test loss 2.513283, test error 55.47
# Epoch   900, train loss 0.678849, train error 23.30,  test loss 2.646475, test error 55.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.118719, train error 79.65,  test loss 2.092801, test error 78.70
# Epoch   100, train loss 0.993922, train error 31.47,  test loss 1.410573, test error 48.75
# Epoch   200, train loss 0.789614, train error 26.25,  test loss 1.724267, test error 50.40
# Epoch   300, train loss 0.684359, train error 21.85,  test loss 2.022388, test error 52.58
# Epoch   400, train loss 0.621524, train error 20.55,  test loss 2.368070, test error 53.65
# Epoch   500, train loss 0.569401, train error 18.57,  test loss 2.679635, test error 54.20
# Epoch   600, train loss 0.560455, train error 19.40,  test loss 3.036629, test error 56.03
# Epoch   700, train loss 0.514230, train error 17.88,  test loss 3.293917, test error 54.83
# Epoch   800, train loss 0.460289, train error 16.32,  test loss 3.594159, test error 55.38
# Epoch   900, train loss 0.498723, train error 17.82,  test loss 3.887919, test error 55.62
# Training model with  40 hidden variables
# Epoch     0, train loss 2.087170, train error 77.10,  test loss 2.028589, test error 76.05
# Epoch   100, train loss 0.903389, train error 29.20,  test loss 1.407604, test error 49.53
# Epoch   200, train loss 0.602237, train error 18.78,  test loss 1.981191, test error 52.95
# Epoch   300, train loss 0.467028, train error 15.25,  test loss 2.696326, test error 53.97
# Epoch   400, train loss 0.375257, train error 11.97,  test loss 3.416243, test error 54.45
# Epoch   500, train loss 0.310549, train error 10.28,  test loss 4.216602, test error 56.05
# Epoch   600, train loss 0.307532, train error 11.12,  test loss 5.031082, test error 56.22
# Epoch   700, train loss 0.223974, train error 7.18,  test loss 5.781136, test error 56.03
# Epoch   800, train loss 0.243266, train error 8.32,  test loss 6.527863, test error 56.30
# Epoch   900, train loss 0.300905, train error 10.78,  test loss 7.159251, test error 57.50
# Training model with  45 hidden variables
# Epoch     0, train loss 2.119730, train error 76.93,  test loss 2.108412, test error 78.35
# Epoch   100, train loss 0.848129, train error 28.55,  test loss 1.571667, test error 53.03
# Epoch   200, train loss 0.518515, train error 16.82,  test loss 2.235826, test error 54.00
# Epoch   300, train loss 0.339798, train error 11.45,  test loss 3.238518, test error 55.50
# Epoch   400, train loss 0.220800, train error 6.97,  test loss 4.398988, test error 55.92
# Epoch   500, train loss 0.174599, train error 5.53,  test loss 5.578616, test error 55.85
# Epoch   600, train loss 0.131131, train error 3.88,  test loss 6.705975, test error 56.38
# Epoch   700, train loss 0.220233, train error 8.30,  test loss 7.774123, test error 56.12
# Epoch   800, train loss 0.011849, train error 0.00,  test loss 8.632020, test error 56.47
# Epoch   900, train loss 0.007682, train error 0.00,  test loss 9.271530, test error 56.35
# Training model with  50 hidden variables
# Epoch     0, train loss 2.036181, train error 76.40,  test loss 1.953519, test error 75.60
# Epoch   100, train loss 0.751601, train error 24.07,  test loss 1.518448, test error 50.95
# Epoch   200, train loss 0.383076, train error 11.40,  test loss 2.476992, test error 53.78
# Epoch   300, train loss 0.175363, train error 4.65,  test loss 3.931524, test error 53.95
# Epoch   400, train loss 0.033092, train error 0.00,  test loss 5.519473, test error 55.17
# Epoch   500, train loss 0.014467, train error 0.00,  test loss 6.528274, test error 55.65
# Epoch   600, train loss 0.009229, train error 0.00,  test loss 7.177583, test error 55.55
# Epoch   700, train loss 0.006497, train error 0.00,  test loss 7.657485, test error 55.67
# Epoch   800, train loss 0.004938, train error 0.00,  test loss 8.045092, test error 55.72
# Epoch   900, train loss 0.003968, train error 0.00,  test loss 8.356742, test error 55.78
# Training model with  55 hidden variables
# Epoch     0, train loss 2.062236, train error 78.45,  test loss 2.014538, test error 76.30
# Epoch   100, train loss 0.633882, train error 18.43,  test loss 1.597350, test error 50.80
# Epoch   200, train loss 0.233559, train error 5.28,  test loss 2.908809, test error 53.65
# Epoch   300, train loss 0.045713, train error 0.05,  test loss 4.633146, test error 54.45
# Epoch   400, train loss 0.015252, train error 0.00,  test loss 5.733793, test error 54.88
# Epoch   500, train loss 0.008700, train error 0.00,  test loss 6.368569, test error 55.30
# Epoch   600, train loss 0.005912, train error 0.00,  test loss 6.809592, test error 55.38
# Epoch   700, train loss 0.004371, train error 0.00,  test loss 7.153850, test error 55.35
# Epoch   800, train loss 0.003476, train error 0.00,  test loss 7.431324, test error 55.33
# Epoch   900, train loss 0.002830, train error 0.00,  test loss 7.669928, test error 55.47
# Training model with  60 hidden variables
# Epoch     0, train loss 2.073797, train error 75.97,  test loss 2.027378, test error 77.15
# Epoch   100, train loss 0.582273, train error 17.32,  test loss 1.723621, test error 51.00
# Epoch   200, train loss 0.150695, train error 2.47,  test loss 3.218556, test error 53.97
# Epoch   300, train loss 0.023413, train error 0.00,  test loss 4.669423, test error 54.75
# Epoch   400, train loss 0.010663, train error 0.00,  test loss 5.428915, test error 55.00
# Epoch   500, train loss 0.006530, train error 0.00,  test loss 5.906425, test error 55.30
# Epoch   600, train loss 0.004616, train error 0.00,  test loss 6.256814, test error 55.33
# Epoch   700, train loss 0.003509, train error 0.00,  test loss 6.533860, test error 55.40
# Epoch   800, train loss 0.002811, train error 0.00,  test loss 6.757648, test error 55.33
# Epoch   900, train loss 0.002329, train error 0.00,  test loss 6.949152, test error 55.30
# Training model with  70 hidden variables
# Epoch     0, train loss 2.017444, train error 74.75,  test loss 1.971714, test error 74.68
# Epoch   100, train loss 0.376811, train error 10.12,  test loss 1.895443, test error 51.47
# Epoch   200, train loss 0.034158, train error 0.00,  test loss 3.465106, test error 53.53
# Epoch   300, train loss 0.011305, train error 0.00,  test loss 4.229347, test error 53.88
# Epoch   400, train loss 0.006383, train error 0.00,  test loss 4.656737, test error 53.88
# Epoch   500, train loss 0.004251, train error 0.00,  test loss 4.961953, test error 54.10
# Epoch   600, train loss 0.003155, train error 0.00,  test loss 5.198403, test error 54.33
# Epoch   700, train loss 0.002468, train error 0.00,  test loss 5.385661, test error 54.38
# Epoch   800, train loss 0.002015, train error 0.00,  test loss 5.542944, test error 54.50
# Epoch   900, train loss 0.001693, train error 0.00,  test loss 5.676647, test error 54.55
# Training model with  80 hidden variables
# Epoch     0, train loss 2.046899, train error 76.60,  test loss 2.004377, test error 75.28
# Epoch   100, train loss 0.222774, train error 3.53,  test loss 2.130837, test error 51.05
# Epoch   200, train loss 0.019571, train error 0.00,  test loss 3.496290, test error 52.08
# Epoch   300, train loss 0.007984, train error 0.00,  test loss 4.052699, test error 52.15
# Epoch   400, train loss 0.004757, train error 0.00,  test loss 4.382630, test error 52.15
# Epoch   500, train loss 0.003276, train error 0.00,  test loss 4.616641, test error 52.20
# Epoch   600, train loss 0.002465, train error 0.00,  test loss 4.800682, test error 52.47
# Epoch   700, train loss 0.001962, train error 0.00,  test loss 4.948579, test error 52.45
# Epoch   800, train loss 0.001615, train error 0.00,  test loss 5.075789, test error 52.50
# Epoch   900, train loss 0.001367, train error 0.00,  test loss 5.184727, test error 52.50
# Training model with  90 hidden variables
# Epoch     0, train loss 2.011465, train error 74.97,  test loss 1.943727, test error 74.62
# Epoch   100, train loss 0.128076, train error 0.88,  test loss 2.226797, test error 51.42
# Epoch   200, train loss 0.014553, train error 0.00,  test loss 3.265885, test error 51.88
# Epoch   300, train loss 0.006420, train error 0.00,  test loss 3.706376, test error 52.38
# Epoch   400, train loss 0.003929, train error 0.00,  test loss 3.973223, test error 52.25
# Epoch   500, train loss 0.002765, train error 0.00,  test loss 4.166952, test error 52.22
# Epoch   600, train loss 0.002103, train error 0.00,  test loss 4.320358, test error 52.35
# Epoch   700, train loss 0.001682, train error 0.00,  test loss 4.445606, test error 52.25
# Epoch   800, train loss 0.001393, train error 0.00,  test loss 4.551521, test error 52.25
# Epoch   900, train loss 0.001183, train error 0.00,  test loss 4.643618, test error 52.28
# Training model with 100 hidden variables
# Epoch     0, train loss 2.034707, train error 75.22,  test loss 1.997484, test error 74.25
# Epoch   100, train loss 0.093896, train error 0.10,  test loss 2.159522, test error 51.15
# Epoch   200, train loss 0.012274, train error 0.00,  test loss 2.977585, test error 51.03
# Epoch   300, train loss 0.005715, train error 0.00,  test loss 3.335127, test error 51.17
# Epoch   400, train loss 0.003578, train error 0.00,  test loss 3.555338, test error 51.17
# Epoch   500, train loss 0.002542, train error 0.00,  test loss 3.719393, test error 51.25
# Epoch   600, train loss 0.001951, train error 0.00,  test loss 3.850453, test error 51.38
# Epoch   700, train loss 0.001567, train error 0.00,  test loss 3.953185, test error 51.50
# Epoch   800, train loss 0.001302, train error 0.00,  test loss 4.044234, test error 51.38
# Epoch   900, train loss 0.001110, train error 0.00,  test loss 4.123182, test error 51.25
# Training model with 120 hidden variables
# Epoch     0, train loss 1.973426, train error 74.07,  test loss 1.908589, test error 73.68
# Epoch   100, train loss 0.052263, train error 0.00,  test loss 2.198871, test error 49.22
# Epoch   200, train loss 0.009651, train error 0.00,  test loss 2.823575, test error 49.20
# Epoch   300, train loss 0.004728, train error 0.00,  test loss 3.106045, test error 49.38
# Epoch   400, train loss 0.003017, train error 0.00,  test loss 3.286951, test error 49.53
# Epoch   500, train loss 0.002172, train error 0.00,  test loss 3.420098, test error 49.50
# Epoch   600, train loss 0.001677, train error 0.00,  test loss 3.525436, test error 49.65
# Epoch   700, train loss 0.001355, train error 0.00,  test loss 3.613079, test error 49.67
# Epoch   800, train loss 0.001131, train error 0.00,  test loss 3.687926, test error 49.72
# Epoch   900, train loss 0.000966, train error 0.00,  test loss 3.752218, test error 49.75
# Training model with 140 hidden variables
# Epoch     0, train loss 1.992584, train error 73.12,  test loss 1.940317, test error 75.47
# Epoch   100, train loss 0.035393, train error 0.00,  test loss 2.131291, test error 48.33
# Epoch   200, train loss 0.008100, train error 0.00,  test loss 2.617750, test error 48.75
# Epoch   300, train loss 0.004155, train error 0.00,  test loss 2.848568, test error 49.03
# Epoch   400, train loss 0.002699, train error 0.00,  test loss 2.998620, test error 49.00
# Epoch   500, train loss 0.001963, train error 0.00,  test loss 3.110729, test error 49.03
# Epoch   600, train loss 0.001526, train error 0.00,  test loss 3.200626, test error 49.10
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.274991, test error 49.28
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.338389, test error 49.22
# Epoch   900, train loss 0.000888, train error 0.00,  test loss 3.393010, test error 49.20
# Training model with 160 hidden variables
# Epoch     0, train loss 1.965932, train error 73.03,  test loss 1.908616, test error 73.40
# Epoch   100, train loss 0.028137, train error 0.00,  test loss 2.174196, test error 49.75
# Epoch   200, train loss 0.007093, train error 0.00,  test loss 2.599576, test error 49.95
# Epoch   300, train loss 0.003735, train error 0.00,  test loss 2.810192, test error 50.17
# Epoch   400, train loss 0.002454, train error 0.00,  test loss 2.950861, test error 50.05
# Epoch   500, train loss 0.001798, train error 0.00,  test loss 3.056026, test error 50.03
# Epoch   600, train loss 0.001405, train error 0.00,  test loss 3.140316, test error 50.03
# Epoch   700, train loss 0.001144, train error 0.00,  test loss 3.209978, test error 50.03
# Epoch   800, train loss 0.000961, train error 0.00,  test loss 3.269504, test error 49.90
# Epoch   900, train loss 0.000825, train error 0.00,  test loss 3.321546, test error 49.80
# Training model with 180 hidden variables
# Epoch     0, train loss 1.907721, train error 70.88,  test loss 1.854623, test error 71.35
# Epoch   100, train loss 0.024403, train error 0.00,  test loss 2.133518, test error 49.25
# Epoch   200, train loss 0.006587, train error 0.00,  test loss 2.495604, test error 49.28
# Epoch   300, train loss 0.003534, train error 0.00,  test loss 2.675706, test error 49.28
# Epoch   400, train loss 0.002342, train error 0.00,  test loss 2.798583, test error 49.35
# Epoch   500, train loss 0.001724, train error 0.00,  test loss 2.888343, test error 49.20
# Epoch   600, train loss 0.001350, train error 0.00,  test loss 2.960820, test error 49.25
# Epoch   700, train loss 0.001102, train error 0.00,  test loss 3.021546, test error 49.38
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 3.073958, test error 49.50
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.119406, test error 49.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.923906, train error 70.28,  test loss 1.848281, test error 71.90
# Epoch   100, train loss 0.020751, train error 0.00,  test loss 2.016954, test error 48.42
# Epoch   200, train loss 0.005979, train error 0.00,  test loss 2.325780, test error 48.38
# Epoch   300, train loss 0.003258, train error 0.00,  test loss 2.484739, test error 48.30
# Epoch   400, train loss 0.002177, train error 0.00,  test loss 2.592618, test error 48.20
# Epoch   500, train loss 0.001610, train error 0.00,  test loss 2.673668, test error 48.15
# Epoch   600, train loss 0.001266, train error 0.00,  test loss 2.739167, test error 48.22
# Epoch   700, train loss 0.001036, train error 0.00,  test loss 2.793434, test error 48.03
# Epoch   800, train loss 0.000873, train error 0.00,  test loss 2.839905, test error 48.30
# Epoch   900, train loss 0.000752, train error 0.00,  test loss 2.880950, test error 48.20
# Training model with 250 hidden variables
# Epoch     0, train loss 1.887487, train error 67.22,  test loss 1.799355, test error 69.30
# Epoch   100, train loss 0.016350, train error 0.00,  test loss 1.900359, test error 47.22
# Epoch   200, train loss 0.005200, train error 0.00,  test loss 2.148312, test error 47.17
# Epoch   300, train loss 0.002904, train error 0.00,  test loss 2.279166, test error 47.22
# Epoch   400, train loss 0.001963, train error 0.00,  test loss 2.368821, test error 47.12
# Epoch   500, train loss 0.001463, train error 0.00,  test loss 2.437720, test error 47.08
# Epoch   600, train loss 0.001155, train error 0.00,  test loss 2.491950, test error 46.83
# Epoch   700, train loss 0.000949, train error 0.00,  test loss 2.539178, test error 46.83
# Epoch   800, train loss 0.000801, train error 0.00,  test loss 2.578457, test error 46.80
# Epoch   900, train loss 0.000691, train error 0.00,  test loss 2.613444, test error 46.78
# Training model with 300 hidden variables
# Epoch     0, train loss 1.859930, train error 66.50,  test loss 1.784724, test error 69.07
# Epoch   100, train loss 0.014577, train error 0.00,  test loss 1.832196, test error 46.10
# Epoch   200, train loss 0.004834, train error 0.00,  test loss 2.042891, test error 45.97
# Epoch   300, train loss 0.002738, train error 0.00,  test loss 2.159569, test error 46.05
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.239264, test error 45.90
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.300211, test error 45.72
# Epoch   600, train loss 0.001103, train error 0.00,  test loss 2.349507, test error 45.67
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.390702, test error 45.72
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.426316, test error 45.70
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.458150, test error 45.72
# Training model with 400 hidden variables
# Epoch     0, train loss 1.858974, train error 68.38,  test loss 1.800729, test error 70.05
# Epoch   100, train loss 0.011690, train error 0.00,  test loss 1.747813, test error 45.55
# Epoch   200, train loss 0.004172, train error 0.00,  test loss 1.920250, test error 45.22
# Epoch   300, train loss 0.002416, train error 0.00,  test loss 2.015256, test error 45.35
# Epoch   400, train loss 0.001664, train error 0.00,  test loss 2.080954, test error 45.33
# Epoch   500, train loss 0.001254, train error 0.00,  test loss 2.131554, test error 45.42
# Epoch   600, train loss 0.000998, train error 0.00,  test loss 2.173122, test error 45.40
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.207454, test error 45.42
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.237547, test error 45.45
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.263585, test error 45.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
