# %% [markdown]
# <a href="https://colab.research.google.com/github/Joan947/UndDL_NotebooksSolved/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9nwgj1x8
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9nwgj1x8
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=98208e4a050dd5c4031b766973485a8d54d598e056723602f07470416b3c0a0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fr48xrf9/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k_2 = 150   # Hidden dimensions
D_k_1 = 250
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):

model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k_1),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k_1, D_k_2),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k_2, D_k_2),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k_2, D_k_1),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k_1, D_o)
)
def weights_init(layer_in):
    # Check if the layer is an instance of nn.Linear.
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_normal_(layer_in.weight, nonlinearity="relu")
        if layer_in.bias is not None:
            #nn.init.constant_(layer_in.bias, 0.0)
            layer_in.bias.data.fill_(0.0)

    print("Initializing layer:", layer_in)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer: Linear(in_features=40, out_features=250, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=250, out_features=150, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=150, out_features=150, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=150, out_features=250, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=250, out_features=10, bias=True)
# Initializing layer: Sequential(
#   (0): Linear(in_features=40, out_features=250, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=250, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=150, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=150, out_features=250, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=250, out_features=10, bias=True)
# )
# Sequential(
#   (0): Linear(in_features=40, out_features=250, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=250, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=150, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=150, out_features=250, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=250, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer: Linear(in_features=40, out_features=100, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=100, out_features=100, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=100, out_features=100, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=100, out_features=10, bias=True)
# Initializing layer: Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )
# Epoch     0, train loss 1.566212, train error 59.62,  test loss 1.658504, test error 66.70
# Epoch     1, train loss 1.309441, train error 49.33,  test loss 1.476432, test error 59.80
# Epoch     2, train loss 1.118967, train error 41.60,  test loss 1.325554, test error 51.10
# Epoch     3, train loss 0.959299, train error 35.20,  test loss 1.286962, test error 50.30
# Epoch     4, train loss 0.837651, train error 30.20,  test loss 1.173276, test error 45.80
# Epoch     5, train loss 0.733486, train error 27.43,  test loss 1.149634, test error 43.90
# Epoch     6, train loss 0.597428, train error 21.53,  test loss 1.114782, test error 40.30
# Epoch     7, train loss 0.545778, train error 18.95,  test loss 1.118221, test error 42.30
# Epoch     8, train loss 0.461236, train error 16.22,  test loss 1.128608, test error 41.20
# Epoch     9, train loss 0.428776, train error 15.82,  test loss 1.160300, test error 38.20
# Epoch    10, train loss 0.251965, train error 6.82,  test loss 1.042378, test error 35.20
# Epoch    11, train loss 0.207382, train error 5.28,  test loss 1.077647, test error 36.00
# Epoch    12, train loss 0.174398, train error 4.05,  test loss 1.140856, test error 36.20
# Epoch    13, train loss 0.141184, train error 2.80,  test loss 1.123032, test error 35.10
# Epoch    14, train loss 0.108030, train error 1.47,  test loss 1.156747, test error 35.40
# Epoch    15, train loss 0.093884, train error 1.00,  test loss 1.204430, test error 35.10
# Epoch    16, train loss 0.074162, train error 0.68,  test loss 1.271099, test error 36.00
# Epoch    17, train loss 0.061571, train error 0.40,  test loss 1.300814, test error 35.00
# Epoch    18, train loss 0.053191, train error 0.40,  test loss 1.355369, test error 36.20
# Epoch    19, train loss 0.038502, train error 0.03,  test loss 1.398908, test error 35.00
# Epoch    20, train loss 0.030275, train error 0.00,  test loss 1.381797, test error 35.60
# Epoch    21, train loss 0.026950, train error 0.00,  test loss 1.400445, test error 35.60
# Epoch    22, train loss 0.024941, train error 0.00,  test loss 1.409153, test error 35.70
# Epoch    23, train loss 0.023135, train error 0.00,  test loss 1.433504, test error 35.70
# Epoch    24, train loss 0.021654, train error 0.00,  test loss 1.448263, test error 35.70
# Epoch    25, train loss 0.020609, train error 0.00,  test loss 1.458454, test error 35.40
# Epoch    26, train loss 0.019325, train error 0.00,  test loss 1.471386, test error 35.30
# Epoch    27, train loss 0.018061, train error 0.00,  test loss 1.487170, test error 35.60
# Epoch    28, train loss 0.017100, train error 0.00,  test loss 1.503524, test error 35.60
# Epoch    29, train loss 0.016342, train error 0.00,  test loss 1.519341, test error 36.00
# Epoch    30, train loss 0.015675, train error 0.00,  test loss 1.521063, test error 35.90
# Epoch    31, train loss 0.015301, train error 0.00,  test loss 1.524760, test error 35.70
# Epoch    32, train loss 0.014907, train error 0.00,  test loss 1.531752, test error 35.90
# Epoch    33, train loss 0.014592, train error 0.00,  test loss 1.535701, test error 35.50
# Epoch    34, train loss 0.014243, train error 0.00,  test loss 1.545497, test error 36.00
# Epoch    35, train loss 0.013958, train error 0.00,  test loss 1.552184, test error 35.80
# Epoch    36, train loss 0.013629, train error 0.00,  test loss 1.553095, test error 35.90
# Epoch    37, train loss 0.013306, train error 0.00,  test loss 1.560804, test error 36.10
# Epoch    38, train loss 0.013033, train error 0.00,  test loss 1.566295, test error 35.70
# Epoch    39, train loss 0.012751, train error 0.00,  test loss 1.570060, test error 36.00
# Epoch    40, train loss 0.012591, train error 0.00,  test loss 1.574126, test error 36.00
# Epoch    41, train loss 0.012485, train error 0.00,  test loss 1.575285, test error 35.80
# Epoch    42, train loss 0.012329, train error 0.00,  test loss 1.579693, test error 35.80
# Epoch    43, train loss 0.012203, train error 0.00,  test loss 1.581889, test error 36.00
# Epoch    44, train loss 0.012079, train error 0.00,  test loss 1.584244, test error 36.00
# Epoch    45, train loss 0.011961, train error 0.00,  test loss 1.586617, test error 35.90
# Epoch    46, train loss 0.011840, train error 0.00,  test loss 1.588463, test error 35.90
# Epoch    47, train loss 0.011722, train error 0.00,  test loss 1.591695, test error 35.90
# Epoch    48, train loss 0.011614, train error 0.00,  test loss 1.594719, test error 35.90
# Epoch    49, train loss 0.011495, train error 0.00,  test loss 1.596636, test error 35.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.15, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=50, gamma=0.75)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=50, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 75
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer: Linear(in_features=40, out_features=250, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=250, out_features=150, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=150, out_features=150, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=150, out_features=250, bias=True)
# Initializing layer: ReLU()
# Initializing layer: Linear(in_features=250, out_features=10, bias=True)
# Initializing layer: Sequential(
#   (0): Linear(in_features=40, out_features=250, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=250, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=150, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=150, out_features=250, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=250, out_features=10, bias=True)
# )
# Epoch     0, train loss 1.595883, train error 62.00,  test loss 1.636219, test error 63.50
# Epoch     1, train loss 1.465159, train error 61.05,  test loss 1.532608, test error 64.90
# Epoch     2, train loss 1.662399, train error 65.38,  test loss 1.748865, test error 69.40
# Epoch     3, train loss 1.511388, train error 59.00,  test loss 1.559646, test error 61.00
# Epoch     4, train loss 1.502796, train error 58.67,  test loss 1.635885, test error 61.70
# Epoch     5, train loss 1.429580, train error 58.22,  test loss 1.535587, test error 60.20
# Epoch     6, train loss 1.456327, train error 58.42,  test loss 1.611492, test error 62.10
# Epoch     7, train loss 1.308232, train error 52.95,  test loss 1.434483, test error 57.80
# Epoch     8, train loss 1.453492, train error 57.40,  test loss 1.582147, test error 59.00
# Epoch     9, train loss 1.416502, train error 54.53,  test loss 1.588385, test error 58.10
# Epoch    10, train loss 1.492728, train error 57.47,  test loss 1.615166, test error 60.90
# Epoch    11, train loss 1.365892, train error 55.28,  test loss 1.474197, test error 58.20
# Epoch    12, train loss 1.464412, train error 56.72,  test loss 1.637518, test error 60.60
# Epoch    13, train loss 1.707882, train error 63.85,  test loss 1.800764, test error 68.00
# Epoch    14, train loss 1.403845, train error 55.15,  test loss 1.474905, test error 57.30
# Epoch    15, train loss 1.583150, train error 59.97,  test loss 1.692956, test error 63.20
# Epoch    16, train loss 1.501666, train error 58.10,  test loss 1.630228, test error 64.20
# Epoch    17, train loss 1.715263, train error 65.72,  test loss 1.770102, test error 66.90
# Epoch    18, train loss 1.553180, train error 62.10,  test loss 1.608074, test error 63.90
# Epoch    19, train loss 1.590328, train error 57.83,  test loss 1.706465, test error 62.30
# Epoch    20, train loss 1.734699, train error 64.28,  test loss 1.833231, test error 68.00
# Epoch    21, train loss 1.469438, train error 59.47,  test loss 1.610785, test error 62.40
# Epoch    22, train loss 2.059005, train error 67.93,  test loss 2.034868, test error 69.30
# Epoch    23, train loss 1.528760, train error 58.15,  test loss 1.639147, test error 63.20
# Epoch    24, train loss 1.437377, train error 55.55,  test loss 1.516204, test error 58.90
# Epoch    25, train loss 1.661613, train error 57.83,  test loss 1.887322, test error 62.20
# Epoch    26, train loss 1.509791, train error 60.17,  test loss 1.544002, test error 63.10
# Epoch    27, train loss 1.489390, train error 58.47,  test loss 1.575303, test error 59.00
# Epoch    28, train loss 2.111413, train error 73.85,  test loss 2.202478, test error 75.90
# Epoch    29, train loss 1.848690, train error 69.10,  test loss 1.970672, test error 72.00
# Epoch    30, train loss 1.625456, train error 65.20,  test loss 1.703143, test error 66.30
# Epoch    31, train loss 1.798728, train error 70.12,  test loss 1.899595, test error 72.50
# Epoch    32, train loss 1.874757, train error 73.62,  test loss 1.921450, test error 74.20
# Epoch    33, train loss 2.253953, train error 80.38,  test loss 2.200001, test error 81.80
# Epoch    34, train loss 1.930959, train error 77.47,  test loss 1.933623, test error 77.50
# Epoch    35, train loss 2.196342, train error 82.85,  test loss 2.215914, test error 82.60
# Epoch    36, train loss 2.106913, train error 84.15,  test loss 2.105209, test error 83.70
# Epoch    37, train loss 2.037359, train error 80.47,  test loss 2.030593, test error 80.00
# Epoch    38, train loss 2.175435, train error 83.53,  test loss 2.178358, test error 82.80
# Epoch    39, train loss 2.059732, train error 81.85,  test loss 2.062224, test error 81.50
# Epoch    40, train loss 2.099617, train error 80.85,  test loss 2.100456, test error 81.10
# Epoch    41, train loss 2.059624, train error 81.15,  test loss 2.072437, test error 82.60
# Epoch    42, train loss 2.085522, train error 83.50,  test loss 2.086170, test error 82.80
# Epoch    43, train loss 2.058022, train error 80.57,  test loss 2.054405, test error 81.20
# Epoch    44, train loss 2.022487, train error 80.82,  test loss 2.011668, test error 80.70
# Epoch    45, train loss 2.043411, train error 80.93,  test loss 2.027771, test error 80.80
# Epoch    46, train loss 2.067522, train error 81.80,  test loss 2.049743, test error 82.60
# Epoch    47, train loss 2.066195, train error 82.00,  test loss 2.073675, test error 81.90
# Epoch    48, train loss 2.079031, train error 81.00,  test loss 2.069697, test error 81.30
# Epoch    49, train loss 2.162054, train error 85.28,  test loss 2.140355, test error 84.20
# Epoch    50, train loss 2.090199, train error 81.95,  test loss 2.062063, test error 81.50
# Epoch    51, train loss 2.090737, train error 82.20,  test loss 2.074709, test error 82.90
# Epoch    52, train loss 2.061049, train error 80.68,  test loss 2.040199, test error 81.00
# Epoch    53, train loss 2.019847, train error 81.50,  test loss 1.998809, test error 82.20
# Epoch    54, train loss 2.004540, train error 81.25,  test loss 1.987965, test error 80.40
# Epoch    55, train loss 2.019118, train error 82.38,  test loss 2.001101, test error 80.80
# Epoch    56, train loss 2.036774, train error 83.35,  test loss 2.016478, test error 82.70
# Epoch    57, train loss 2.002654, train error 81.07,  test loss 1.987212, test error 80.00
# Epoch    58, train loss 1.987485, train error 80.10,  test loss 1.964231, test error 80.20
# Epoch    59, train loss 1.991898, train error 80.65,  test loss 1.962376, test error 80.30
# Epoch    60, train loss 1.988975, train error 80.05,  test loss 1.967080, test error 80.10
# Epoch    61, train loss 2.056572, train error 81.93,  test loss 2.049405, test error 81.10
# Epoch    62, train loss 2.011005, train error 81.85,  test loss 2.012094, test error 81.00
# Epoch    63, train loss 2.001312, train error 82.55,  test loss 1.978125, test error 81.30
# Epoch    64, train loss 1.987458, train error 80.78,  test loss 1.975600, test error 80.20
# Epoch    65, train loss 1.987715, train error 81.25,  test loss 1.967432, test error 81.00
# Epoch    66, train loss 1.988722, train error 80.35,  test loss 1.977221, test error 80.50
# Epoch    67, train loss 2.067473, train error 81.45,  test loss 2.094917, test error 83.00
# Epoch    68, train loss 2.060245, train error 80.88,  test loss 2.077245, test error 81.60
# Epoch    69, train loss 2.042770, train error 83.60,  test loss 2.031882, test error 84.00
# Epoch    70, train loss 2.017490, train error 80.75,  test loss 2.008058, test error 79.90
# Epoch    71, train loss 2.028602, train error 81.55,  test loss 2.021293, test error 80.80
# Epoch    72, train loss 2.023273, train error 80.95,  test loss 2.004940, test error 80.70
# Epoch    73, train loss 2.011233, train error 81.53,  test loss 2.003439, test error 82.30
# Epoch    74, train loss 2.051586, train error 81.12,  test loss 2.074288, test error 81.10

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
