# %% [markdown]
# <a href="https://colab.research.google.com/github/Joan947/UndDL_NotebooksSolved/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/guochengqian/PointNeXt.git
# Out:
# Cloning into 'PointNeXt'...
# remote: Enumerating objects: 723, done.
# remote: Counting objects: 100% (324/324), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 723 (delta 243), reused 181 (delta 181), pack-reused 399 (from 1)
# Receiving objects: 100% (723/723), 5.22 MiB | 23.77 MiB/s, done.
# Resolving deltas: 100% (427/427), done.

# %%
# %cd PointNeXt
# Out:
# /content/PointNeXt

# %%
# !git clone https://github.com/guochengqian/openpoints.git
# Out:
# Cloning into 'openpoints'...
# remote: Enumerating objects: 514, done.
# remote: Counting objects: 100% (358/358), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 514 (delta 176), reused 150 (delta 150), pack-reused 156 (from 1)
# Receiving objects: 100% (514/514), 437.81 KiB | 10.68 MiB/s, done.
# Resolving deltas: 100% (209/209), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 24.11.2

# %% [markdown]
# Open Install.sh and make some changes

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda init
# conda deactivate
# conda env remove --name openpoints
# conda init
# conda create -n openpoints -y python=3.11
# conda activate openpoints
# conda info --envs
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# EnvironmentLocationNotFound: Not a conda environment: /usr/local/envs/openpoints
#
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)"
#
# conda activate openpoints
# conda info --envs
# conda install pytorch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 pytorch-cuda=11.8 -c pytorch -c nvidia
# pip install torch-scatter -f https://data.pyg.org/whl/torch-2.1.2+cu118.html
# Out:
# # conda environments:
# #
# base                   /usr/local
# openpoints           * /usr/local/envs/openpoints
#
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/openpoints
#
#   added / updated specs:
#     - pytorch-cuda=11.8
#     - pytorch==2.1.2
#     - torchaudio==2.1.2
#     - torchvision==0.16.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       3_kmp_llvm           7 KB  conda-forge
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
# ...

# %%
# !python --version
# %cd PointNeXt
# Out:
# Python 3.11.11
# /content/PointNeXt

# %%
# !pip install -r requirements.txt

# %%
# %%shell
# cd openpoints/cpp/pointnet2_batch
# python setup.py install
# cd ../
# Out:
# running install
# /usr/local/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating pointnet2_cuda.egg-info
# writing pointnet2_cuda.egg-info/PKG-INFO
# writing dependency_links to pointnet2_cuda.egg-info/dependency_links.txt
# writing top-level names to pointnet2_cuda.egg-info/top_level.txt
# writing manifest file 'pointnet2_cuda.egg-info/SOURCES.txt'
# reading manifest file 'pointnet2_cuda.egg-info/SOURCES.txt'
# writing manifest file 'pointnet2_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# ...

# %%
from google.colab import userdata
import wandb

WANDB_API_KEY = userdata.get('WANDB_API_KEY')
if WANDB_API_KEY:
    wandb.login(key=WANDB_API_KEY)
else:
    print("W&B API Key not found in Colab. Please login manually.")
    wandb.login()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: owusujoanakonadu (owusujoanakonadu-university-of-wyoming) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !ls "/content/drive/MyDrive/PointNextdatasets"
# Out:
# ls: cannot access '/content/drive/MyDrive/PointNextdatasets': No such file or directory

# %%
# !cd data && mkdir ShapeNetPart && cd ShapeNetPart

# %%
# !ln -s $"/content/drive/MyDrive/PointNextdatasets/shapenetpart/shapenetcore_partanno_segmentation_benchmark_v0_normal" "/content/PointNeXt/data/ShapeNetPart"
# Out:
# ln: failed to create symbolic link '/content/PointNeXt/data/ShapeNetPart/shapenetcore_partanno_segmentation_benchmark_v0_normal': File exists

# %% [markdown]
# Testing

# %%
CUDA_VISIBLE_DEVICES=0 python examples/shapenetpart/main.py --cfg cfgs/shapenetpart/pointnext-s.yaml mode=test --pretrained_path /content/drive/MyDrive/shapenetpart-train-pointnext-s_c160/checkpoint/shapenetpart-train-pointnext-s_c160-ngpus4-seed6692-20220821-200729-kZfzCKh7kJ7n3chYLBSXrr_ckpt_best.pth
# Out:
# ShapeNetPart
